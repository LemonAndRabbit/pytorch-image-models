# %%
from sparsity_util import read_sparsity_info
import numpy as np

# %% [markdown]
# # Read SparsityInfo from file

# %%
b = read_sparsity_info('block_11_channels_input_gelu.spi')
print(b.shape)
print(np.average(b.avg))
# Out:
# (196, 3072)
# 0.12457722230447243

# %%
b1 = b.slice_batch(0, 128)
b2 = b.slice_batch(128, 256)

# %% [markdown]
# # Visualize

# %%
# %matplotlib notebook

from sparsity_util import SparsityMap3D, SparsityMap2D, SparsityMap1D

# %%
b1_map = SparsityMap2D(b1.avg)
b2_map = SparsityMap2D(b2.avg)

# %%
fig = b1_map.draw()
fig.set_figheight(10)
fig.set_figwidth(8)
# Out:
# <img src="data:image/png;base64,..." width="1000">
